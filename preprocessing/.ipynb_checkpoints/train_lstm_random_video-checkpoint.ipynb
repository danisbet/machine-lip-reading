# %%
from data import load_data
import matplotlib.pyplot as plt
import os
import numpy as np

import time

from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.model_selection import train_test_split

from keras.models import Model
from keras.layers.wrappers import TimeDistributed, Bidirectional
from keras.layers.recurrent import GRU
from keras.layers import Input
from keras.layers.convolutional import Conv2D, MaxPooling2D, ZeroPadding3D
from keras.layers.core import Lambda, Dropout, Flatten, Dense, Activation
from keras.optimizers import Adam
from keras import backend as K
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))
# Using TensorFlow backend.

# %%
CURRENT_PATH = '/home/ubuntu/assignments/machine-lip-reading/preprocessing'
DATA_PATH = CURRENT_PATH + '/../data'

# %%
def ctc_lambda_func(args):
    import tensorflow as tf
    y_pred, labels, input_length, label_length = args
    # From Keras example image_ocr.py:
    # the 2 is critical here since the first couple outputs of the RNN
    # tend to be garbage:
    # y_pred = y_pred[:, 2:, :]
    label_length = K.cast(tf.squeeze(label_length),'int32')
    input_length = K.cast(tf.squeeze(input_length),'int32')
    labels = K.ctc_label_dense_to_sparse(labels, label_length)
    #y_pred = y_pred[:, :, :]
    #return K.ctc_batch_cost(labels, y_pred, input_length, label_length, ignore_longer_outputs_than_inputs=True)
    return tf.nn.ctc_loss(labels, y_pred, input_length, ctc_merge_repeated=False,
                         ignore_longer_outputs_than_inputs = True, time_major = False)

# %%
def CTC(name, args):
	return Lambda(ctc_lambda_func, output_shape=(1,), name=name)(args)

# %%
def build_model(input_size, output_size = 28, max_string_len = 10):
    # model = Sequential()
    input_data = Input(name='the_input', shape=input_size, dtype='float32')
    x = ZeroPadding3D(padding=(0,2,2), name='padding1')(input_data)
    x = TimeDistributed(Conv2D(filters = 32, kernel_size = 5, strides = (2,2),
                             padding = 'same', activation = 'relu'))(x)
    print
    x = TimeDistributed(MaxPooling2D(pool_size=(2,2), strides=None, name='max1'))(x)
    x = Dropout(0.5)(x)

    x = TimeDistributed(Conv2D(filters=32, kernel_size=5, strides=(2, 2),
                               padding='same', activation='relu'))(x)
    x = TimeDistributed(MaxPooling2D(pool_size=(2,2), strides=None, name='max1'))(x)
    x = Dropout(0.5)(x)

    x = TimeDistributed(Conv2D(filters=4, kernel_size=5, strides=(2, 2),
                               padding='same', activation='relu'))(x)
    x = TimeDistributed(MaxPooling2D(pool_size=(2,2), strides=None, name='max1'))(x)
    x = Dropout(0.5)(x)

    input_lstm = TimeDistributed(Flatten())(x)

    x_lstm = Bidirectional(GRU(256, return_sequences=True, kernel_initializer='Orthogonal', name='gru1'), merge_mode='concat')(input_lstm)
    x_lstm = Dense(output_size, kernel_initializer='he_normal', name='dense1')(x_lstm)
    print("after dense1")
    y_pred = Activation('softmax', name='softmax')(x_lstm)

    labels = Input(name='the_labels', shape = [max_string_len], dtype='int32')
    input_length = Input(name = 'input_length', shape =[1], dtype = 'int32')
    label_length = Input(name = 'label_length', shape = [1], dtype = 'int32')
    loss = CTC('ctc',[y_pred, labels, input_length, label_length])
    model = Model(inputs=[input_data, labels, label_length, input_length],
                  outputs = loss)
    model.summary()
    # Build model here...

    return model

# %%
def pad_labels(labels, max_string_len):
    padding = np.ones((labels.shape[0], max_string_len - labels.shape[1])) * -1
    return np.concatenate((labels, padding), axis = 1)

# %%
def train(model, x_train, y_train, label_len_train, input_len_train, batch_size=256, epochs=100, val_train_ratio=0.2):
    max_string_len = 10
    if y_train.shape[1] != max_string_len:
        y_train = pad_labels(y_train, max_string_len)

    adam = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
    model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer=adam)
    history = model.fit(x = {'the_input':x_train, 'the_labels':y_train, 'label_length':label_len_train,
                             'input_length':input_len_train}, y = {'ctc': np.zeros([x_train.shape[0]])},
                        batch_size=batch_size,
                        epochs=epochs,
                        validation_split=val_train_ratio,
                        shuffle=True,
                        verbose=1)

    return history

# %%
def read_data():
    oh = OneHotEncoder()
    le = LabelEncoder()

    x = list()
    y = list()
    t = list()
    print("loading images...")
    for i, (img, words) in enumerate(load_data(DATA_PATH, verbose=False, framebyframe=False)):
        if img.shape[0] != 75:
            continue
        x.append(img)
        y.append(words)

        t += words.tolist()
        if i == 3:
            break

    t = le.fit_transform(t)
    oh.fit(t.reshape(-1, 1))

    print("convering to np array...")
    x = np.stack(x, axis=0)

    print("transforming y...")
    for i in range(len(y)):
        y_ = le.transform(y[i])
        y[i] = np.asarray(oh.transform(y_.reshape(-1, 1)).todense())
    y = np.stack(y, axis=0)

    return x, y

# %%
import numpy as np
import os
from align import read_align
from video import read_video
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
import re

CURRENT_PATH = '/home/ubuntu/assignments/machine-lip-reading/preprocessing'
# CURRENT_PATH = os.path.dirname(os.path.abspath(__file__))
DATA_PATH = CURRENT_PATH + '/../data'
PREDICTOR_PATH = CURRENT_PATH + '/shape_predictor_68_face_landmarks.dat'
SAVE_NUMPY_PATH = CURRENT_PATH + '/../data/numpy_results'


def text_to_labels(text):
    ret = []
    for char in text:
        if char >= 'a' and char <= 'z':
            ret.append(ord(char) - ord('a'))
        elif char == ' ':
            ret.append(26)
    return ret

def labels_to_text(labels):
# 26 is space, 27 is CTC blank char
    text = ''
    for c in labels:
        if c >= 0 and c < 26:
            text += chr(c + ord('a'))
        elif c == 26:
            text += ' '
    return text

# %%
import numpy as np
import os
from align import read_align
from video import read_video
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
import re

CURRENT_PATH = os.path.dirname(os.path.abspath(__file__))
DATA_PATH = CURRENT_PATH + '/../data'
PREDICTOR_PATH = CURRENT_PATH + '/shape_predictor_68_face_landmarks.dat'
SAVE_NUMPY_PATH = CURRENT_PATH + '/../data/numpy_results'


def text_to_labels(text):
    ret = []
    for char in text:
        if char >= 'a' and char <= 'z':
            ret.append(ord(char) - ord('a'))
        elif char == ' ':
            ret.append(26)
    return ret


def labels_to_text(labels):
    # 26 is space, 27 is CTC blank char
    text = ''
    for c in labels:
        if c >= 0 and c < 26:
            text += chr(c + ord('a'))
        elif c == 26:
            text += ' '
    return text


def load_data(datapath, verbose=False, num_samples=-1, ctc_encoding=False):
    oh = OneHotEncoder()
    le = LabelEncoder()

    counter = 0
    done = False

    max_len = 0
    max_word_len = 0

    word_len_list = []
    input_len_list = []

    x_raw = list()
    y_raw = list()

    for root, dirs, files in os.walk(datapath):
        for name in files:
            if '.mpg' in name:
                if verbose is True:
                    print("reading: " + root + "/" + name)

                video = read_video(os.path.join(root, name), PREDICTOR_PATH)
                alignments = read_align(os.path.join(root, '../align/', name.split(".")[0] + ".align"))

                for start, stop, word in alignments:
                    if word == 'sil' or word == 'sp':
                        continue

                    _, d1, d2, d3 = video[start:stop].shape

                    if (len(x_raw) > 0):
                        _, prev_d1, prev_d2, prev_d3 = x_raw[-1].shape
                        if (d1, d2, d3) != (prev_d1, prev_d2, prev_d3):
                            if verbose is True:
                                print("different size, skip")
                            continue

                    x_raw.append(video[start:stop])
                    y_raw.append(word)

                    max_word_len = max(max_word_len, len(word))
                    max_len = max(max_len, stop - start)
                    word_len_list.append(len(word))
                    input_len_list.append(stop - start)

                    counter += 1
                    if counter % num_samples == 0:
                        if not ctc_encoding:
                            y_raw = le.fit_transform(y_raw)
                            y = oh.fit_transform(y_raw.reshape(-1, 1)).todense()

                        for i in range(len(x_raw)):
                            result = np.zeros((max_len, x_raw[i].shape[1], x_raw[i].shape[2], x_raw[i].shape[3]))
                            result[:x_raw[i].shape[0], :x_raw[i].shape[1], :x_raw[i].shape[2], :x_raw[i].shape[3]] = \
                            x_raw[i]
                            x_raw[i] = result

                            if ctc_encoding:
                                res = np.ones(max_word_len) * -1
                                enc = np.array(text_to_labels(y_raw[i]))
                                res[:enc.shape[0]] = enc
                                y_raw[i] = res

                        if ctc_encoding:
                            y = np.stack(y_raw, axis=0)

                        x = np.stack(x_raw, axis=0)
                        np.savez_compressed('data/s1_X_'+str(counter / num_samples), x=x)
                        np.savez_compressed('data/s1_y_'+str(counter / num_samples), y=y)
                        np.savez_compressed('data/s1_wi_'+str(counter / num_samples), word_length=np.array(word_len_list),
                                            input_length=np.array(input_len_list))
                        print ('successfully saving the %d th %d words'%(counter / num_samples, num_samples))
                        x_raw = []
                        y_raw = []
                        word_len_list = []
                        input_len_list = []

    return None


if __name__ == "__main__":
    load_data(DATA_PATH, verbose=False, ctc_encoding=True, num_samples=5000)
    print("X:", X.shape)
    print("y:", y.shape)

# %%
load_data_for_speaker(DATA_PATH, 's1', verbose=True, num_samples=-1, ctc_encoding=True)
# Out:
# recording - 0: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/pwaj8p.mpg
# recording - 1: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bbifzp.mpg
# recording - 2: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bras7s.mpg
# recording - 3: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/sbwh8p.mpg
# recording - 4: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lwwm1s.mpg
# recording - 5: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bgbb2p.mpg
# recording - 6: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lrik4p.mpg
# recording - 7: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lgamzp.mpg
# recording - 8: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/pwwq8n.mpg
# recording - 9: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lrar3a.mpg
# recording - 10: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/prwx9a.mpg
# recording - 11: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/pgbe4p.mpg
# recording - 12: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lrwl6p.mpg
# recording - 13: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/pbwp6n.mpg
# recording - 14: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/swao7a.mpg
# recording - 15: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lwar8p.mpg
# recording - 16: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/swwjzp.mpg
# recording - 17: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/brim1a.mpg
# recording - 18: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/pwax6p.mpg
# recording - 19: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/
/home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lwae8n.mpg
# recording - 446: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/pwbd9a.mpg
# recording - 447: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/srwi4p.mpg
# recording - 448: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lwaz2p.mpg
# recording - 449: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bram3s.mpg
# recording - 450: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/pwbx8n.mpg
# recording - 451: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lwbs3a.mpg
# recording - 452: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/srih3a.mpg
# recording - 453: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lwws7a.mpg
# recording - 454: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/srau3s.mpg
# recording - 455: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bgaa9a.mpg
# recording - 456: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/pbwj3s.mpg
# recording - 457: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lgif2p.mpg
# recording - 458: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lbwr5a.mpg
# recording - 459: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/swib3s.mpg
# recording - 460: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/sbbuzn.mpg
# recording - 461: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/prav8n.mpg
# ...
# recording - 847: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/pbwc8n.mpg
# recording - 848: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lgas4p.mpg
# recording - 849: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lrwl7a.mpg
# recording - 850: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bwwh2n.mpg
# recording - 851: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bgin3a.mpg
# recording - 852: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/pgij9s.mpg
# recording - 853: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/srbb7a.mpg
# recording - 854: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bwaa3a.mpg
# recording - 855: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bwwa8n.mpg
# recording - 856: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/pbib6n.mpg
# recording - 857: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/pgby4n.mpg
# recording - 858: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bgin1s.mpg
# recording - 859: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/sbwb3s.mpg
# recording - 860: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bras6n.mpg
# recording - 861: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/swbc2p.mpg
# recording - 862: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/sbwo2p.mpg
# recording - 863: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bgaa6n.mpg
# recording - 864: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bbws8n.mpg
# recording - 865: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/sban4p.mpg
# recording - 866: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bwbt6n.mpg
# recording - 867: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bris2n.mpg
# recording - 868: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bwba7a.mpg
# recording - 869: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bbir7s.mpg
# recording - 870: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/brbm6n.mpg
# recording - 871: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lrae2n.mpg
# recording - 872: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/pwij3s.mpg
# recording - 873: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/pgwr4n.mpg
# recording - 874: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lgifzn.mpg
# recording - 875: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/pwwy3s.mpg
# recording - 876: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/srwb8n.mpg
# recording - 877: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/sbaa5s.mpg
# recording - 878: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/pbbc5s.mpg
# recording - 879: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bwba4n.mpg
# recording - 880: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/swwp3s.mpg
# recording - 881: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/sgib9s.mpg
# recording - 882: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/srin5s.mpg
# recording - 883: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lgif3a.mpg
# recording - 884: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lgir8n.mpg
# recording - 885: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lwbz6p.mpg
# recording - 886: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/sgwdzn.mpg
# recording - 887: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lbbr1a.mpg
# recording - 888: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bwwu2p.mpg
# recording - 889: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/pwip8p.mpg
# recording - 890: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/pgbk8p.mpg
# recording - 891: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bras9a.mpg
# recording - 892: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bgbh6p.mpg
# recording - 893: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/pgikzp.mpg
# recording - 894: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bgwb4n.mpg
# recording - 895: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bbbs4n.mpg
# recording - 896: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/swio1s.mpg
# recording - 897: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/srwo8p.mpg
# recording - 898: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/prbj4n.mpg
# recording - 899: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bgbozp.mpg
# recording - 900: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/swbo9s.mpg
# recording - 901: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/sbaa7a.mpg
# recording - 902: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bbir9a.mpg
# recording - 903: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bwbg9s.mpg
# recording - 904: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/prip1s.mpg
# recording - 905: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lrwfzn.mpg
# recording - 906: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/sbia3a.mpg
# recording - 907: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/swwi8n.mpg
# recording - 908: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lgil6p.mpg
# recording - 909: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/brbm9a.mpg
# recording - 910: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/brwt7a.mpg
# recording - 911: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bwwh5a.mpg
# recording - 912: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lrae3s.mpg
# recording - 913: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/srab2p.mpg
# recording - 914: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lgwm7s.mpg
# recording - 915: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/prap5s.mpg
# recording - 916: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/brag1a.mpg
# recording - 917: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lgas5a.mpg
# recording - 918: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bwwbzp.mpg
# recording - 919: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bbaf2n.mpg
# recording - 920: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/sbwb4p.mpg
# recording - 921: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/brba1a.mpg
# recording - 922: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/pgaq6n.mpg
# recording - 923: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lrik2n.mpg
# recording - 924: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bbaz4n.mpg
# recording - 925: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/prbp9s.mpg
# recording - 926: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/sban5a.mpg
# recording - 927: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/srao1a.mpg
# recording - 928: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bgwo2n.mpg
# recording - 929: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/swbp1a.mpg
# recording - 930: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/pgiq3s.mpg
# recording - 931: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lbbk4n.mpg
# recording - 932: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bbaszn.mpg
# recording - 933: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lwbl9a.mpg
# recording - 934: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/pgiq2n.mpg
# recording - 935: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lbwe4n.mpg
# recording - 936: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/srwb9s.mpg
# recording - 937: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bwit1a.mpg
# recording - 938: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/swwc7a.mpg
# recording - 939: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/swab8p.mpg
# recording - 940: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/sgap1s.mpg
# recording - 941: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/swwv6n.mpg
# recording - 942: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lriq9a.mpg
# recording - 943: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/swwv9a.mpg
# recording - 944: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/srbo2n.mpg
# recording - 945: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bwaa1s.mpg
# recording - 946: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bgbn8n.mpg
# recording - 947: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lrwl4n.mpg
# recording - 948: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lbaq5s.mpg
# recording - 949: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/swwp4p.mpg
# recording - 950: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/brwnzn.mpg
# recording - 951: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bgbh7a.mpg
# recording - 952: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/sgbj2p.mpg
# recording - 953: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/pbav3s.mpg
# recording - 954: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bgan5s.mpg
# recording - 955: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lbwy8p.mpg
# recording - 956: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/bgahzn.mpg
# recording - 957: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/sbat8p.mpg
# recording - 958: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/pgwr6p.mpg
# recording - 959: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/sgii5a.mpg
# recording - 960: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lrae5a.mpg
# recording - 961: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/sgio7s.mpg
# recording - 962: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/pwwe2p.mpg
# recording - 963: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/sbbn6n.mpg
# recording - 964: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/pgbrzn.mpg
# recording - 965: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/pbio4n.mpg
# recording - 966: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lgaz7s.mpg
# recording - 967: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/swib2n.mpg
# recording - 968: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/prwq4p.mpg
# recording - 969: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/swaizn.mpg
# recording - 970: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/pbwx1s.mpg
# recording - 971: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/srbh8n.mpg
# recording - 972: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/swwc6p.mpg
# recording - 973: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/priv6p.mpg
# recording - 974: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/pgwe9a.mpg
# recording - 975: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/sgbx1a.mpg
# recording - 976: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lrie1a.mpg
# recording - 977: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lrak9a.mpg
# recording - 978: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lwiy8p.mpg
# recording - 979: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/swao6p.mpg
# recording - 980: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/pgwl3a.mpg
# recording - 981: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lbad7s.mpg
# recording - 982: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/brwn1s.mpg
# recording - 983: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/swih9a.mpg
# recording - 984: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/prip3a.mpg
# recording - 985: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lwbl6n.mpg
# recording - 986: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/pwaq2p.mpg
# recording - 987: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/sbbu2p.mpg
# recording - 988: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/swbczn.mpg
# recording - 989: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/sbbn8p.mpg
# recording - 990: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/swiozn.mpg
# recording - 991: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/sbbn9a.mpg
# recording - 992: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lbby4p.mpg
# recording - 993: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/srwi3s.mpg
# recording - 994: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/lbad6n.mpg
# recording - 995: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/pwic9s.mpg
# recording - 996: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/prwq5a.mpg
# recording - 997: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/pripzn.mpg
# recording - 998: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/pwaj7s.mpg
# recording - 999: /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/video/pbav2n.mpg
# 1000
