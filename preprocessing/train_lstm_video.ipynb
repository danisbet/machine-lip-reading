# %%
from data import load_data
import matplotlib.pyplot as plt
import os
import numpy as np

import time

from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.model_selection import train_test_split

from keras.models import Model
from keras.layers.wrappers import TimeDistributed, Bidirectional
from keras.layers.recurrent import GRU
from keras.layers import Input
from keras.layers.convolutional import Conv2D, MaxPooling2D, ZeroPadding3D
from keras.layers.core import Lambda, Dropout, Flatten, Dense, Activation
from keras.optimizers import Adam
from keras import backend as K
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))
# Using TensorFlow backend.

# %%
CURRENT_PATH = '/home/ubuntu/assignments/machine-lip-reading/preprocessing'
DATA_PATH = CURRENT_PATH + '/../data'

# %%
def ctc_lambda_func(args):
    import tensorflow as tf
    y_pred, labels, input_length, label_length = args
    # From Keras example image_ocr.py:
    # the 2 is critical here since the first couple outputs of the RNN
    # tend to be garbage:
    # y_pred = y_pred[:, 2:, :]
    label_length = K.cast(tf.squeeze(label_length),'int32')
    input_length = K.cast(tf.squeeze(input_length),'int32')
    labels = K.ctc_label_dense_to_sparse(labels, label_length)
    #y_pred = y_pred[:, :, :]
    #return K.ctc_batch_cost(labels, y_pred, input_length, label_length, ignore_longer_outputs_than_inputs=True)
    return tf.nn.ctc_loss(labels, y_pred, input_length, ctc_merge_repeated=False,
                         ignore_longer_outputs_than_inputs = True, time_major = False)

# %%
def CTC(name, args):
	return Lambda(ctc_lambda_func, output_shape=(1,), name=name)(args)

# %%
def build_model(input_size, output_size = 28, max_string_len = 10):
    # model = Sequential()
    input_data = Input(name='the_input', shape=input_size, dtype='float32')
    x = ZeroPadding3D(padding=(0,2,2), name='padding1')(input_data)
    x = TimeDistributed(Conv2D(filters = 32, kernel_size = 5, strides = (2,2),
                             padding = 'same', activation = 'relu'))(x)
    print
    x = TimeDistributed(MaxPooling2D(pool_size=(2,2), strides=None, name='max1'))(x)
    x = Dropout(0.5)(x)

    x = TimeDistributed(Conv2D(filters=32, kernel_size=5, strides=(2, 2),
                               padding='same', activation='relu'))(x)
    x = TimeDistributed(MaxPooling2D(pool_size=(2,2), strides=None, name='max1'))(x)
    x = Dropout(0.5)(x)

    x = TimeDistributed(Conv2D(filters=4, kernel_size=5, strides=(2, 2),
                               padding='same', activation='relu'))(x)
    x = TimeDistributed(MaxPooling2D(pool_size=(2,2), strides=None, name='max1'))(x)
    x = Dropout(0.5)(x)

    input_lstm = TimeDistributed(Flatten())(x)

    x_lstm = Bidirectional(GRU(256, return_sequences=True, kernel_initializer='Orthogonal', name='gru1'), merge_mode='concat')(input_lstm)
    x_lstm = Dense(output_size, kernel_initializer='he_normal', name='dense1')(x_lstm)
    print("after dense1")
    y_pred = Activation('softmax', name='softmax')(x_lstm)

    labels = Input(name='the_labels', shape = [max_string_len], dtype='int32')
    input_length = Input(name = 'input_length', shape =[1], dtype = 'int32')
    label_length = Input(name = 'label_length', shape = [1], dtype = 'int32')
    loss = CTC('ctc',[y_pred, labels, input_length, label_length])
    model = Model(inputs=[input_data, labels, label_length, input_length],
                  outputs = loss)
    model.summary()
    # Build model here...

    return model

# %%
def pad_labels(labels, max_string_len):
    padding = np.ones((labels.shape[0], max_string_len - labels.shape[1])) * -1
    return np.concatenate((labels, padding), axis = 1)

# %%
def train(model, x_train, y_train, label_len_train, input_len_train, batch_size=256, epochs=100, val_train_ratio=0.2):
    max_string_len = 10
    if y_train.shape[1] != max_string_len:
        y_train = pad_labels(y_train, max_string_len)

    adam = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
    model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer=adam)
    history = model.fit(x = {'the_input':x_train, 'the_labels':y_train, 'label_length':label_len_train,
                             'input_length':input_len_train}, y = {'ctc': np.zeros([x_train.shape[0]])},
                        batch_size=batch_size,
                        epochs=epochs,
                        validation_split=val_train_ratio,
                        shuffle=True,
                        verbose=1)

    return history

# %%
def read_data():
    oh = OneHotEncoder()
    le = LabelEncoder()

    x = list()
    y = list()
    t = list()
    print("loading images...")
    for i, (img, words) in enumerate(load_data(DATA_PATH, verbose=False, framebyframe=False)):
        if img.shape[0] != 75:
            continue
        x.append(img)
        y.append(words)

        t += words.tolist()
        if i == 3:
            break

    t = le.fit_transform(t)
    oh.fit(t.reshape(-1, 1))

    print("convering to np array...")
    x = np.stack(x, axis=0)

    print("transforming y...")
    for i in range(len(y)):
        y_ = le.transform(y[i])
        y[i] = np.asarray(oh.transform(y_.reshape(-1, 1)).todense())
    y = np.stack(y, axis=0)

    return x, y

# %%
from data_lstm import load_data
CURRENT_PATH = '/home/ubuntu/assignments/machine-lip-reading/preprocessing'
DATA_PATH = CURRENT_PATH + '/../data'
count = load_data(DATA_PATH, 's1')
# Out:
# 0: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwaj8p.mpg
# 6: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobbifzp.mpg
# 12: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobras7s.mpg
# 18: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbwh8p.mpg
# 24: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwwm1s.mpg
# 30: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgbb2p.mpg
# 36: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolrik4p.mpg
# 42: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolgamzp.mpg
# 48: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwwq8n.mpg
# 54: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolrar3a.mpg
# 60: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoprwx9a.mpg
# 66: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgbe4p.mpg
# 72: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolrwl6p.mpg
# 78: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbwp6n.mpg
# 84: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswao7a.mpg
# 90: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwar8p.mpg
# 96: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswwjzp.mpg
# 102: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobrim1a.mpg
# 108: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwax6p.mpg
# 114: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbba9s.mpg
# 120: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobbizzn.mpg
# different size, skip
# different size, skip
# different size, skip
# different size, skip
# different size, skip
# different size, skip
# 120: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbby3s.mpg
# 126: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolrwf2p.mpg
# 132: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgio9a.mpg
# 138: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobriz7s.mpg
# 144: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobbwtzp.mpg
# 150: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgbv9s.mpg
# 156: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgig8p.mpg
# 162: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobriz6n.mpg
# 168: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwwn7s.mpg
# 174: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwwn9a.mpg
# 180: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgio6n.mpg
# 186: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoprbx3s.mpg
# 192: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswao4n.mpg
# 198: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrbh9s.mpg
# 204: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobris5a.mpg
# 210: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbbq8n.mpg
# 216: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobbal8p.mpg
# 222: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbwy6n.mpg
# 228: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolrbzzp.mpg
# 234: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgbr3a.mpg
# 240: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwwf7s.mpg
# 246: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwaq1s.mpg
# 252: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbbj1a.mpg
# 258: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrwv2p.mpg
# 264: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrwi2n.mpg
# 270: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobbwg3a.mpg
# 276: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgwh8n.mpg
# 282: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobrbt1s.mpg
# 288: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoprwx8p.mpg
# 294: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolgaz6n.mpg
# 300: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswiu7a.mpg
# 306: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgwp8n.mpg
# 312: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwwh3s.mpg
# 318: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgbc8p.mpg
# 324: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwaa2p.mpg
# 330: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgby6p.mpg
# 336: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolrik3s.mpg
# 342: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbbp4p.mpg
# 348: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoprwk1a.mpg
# 354: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbij9a.mpg
# 360: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgik1a.mpg
# 366: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolgwm6n.mpg
# 372: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgby5s.mpg
# 378: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwis8n.mpg
# 384: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbiq3a.mpg
# 390: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbwl1a.mpg
# 396: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrwo9a.mpg
# 402: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwwm3a.mpg
# 408: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrwo6n.mpg
# 414: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwazzn.mpg
# 420: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgio8p.mpg
# 426: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbbu1s.mpg
# 432: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgbo1a.mpg
# 438: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbak2p.mpg
# 444: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgwy9s.mpg
# 450: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolrby8n.mpg
# 456: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobbbf9a.mpg
# 462: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolrbe7s.mpg
# 468: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwaz1s.mpg
# 474: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwim5s.mpg
# 480: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwad2n.mpg
# 486: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswavzp.mpg
# 492: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgbu3s.mpg
# 498: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbig6p.mpg
# 504: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolgbm2n.mpg
# 510: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbaa4n.mpg
# 516: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobbwm7a.mpg
# 522: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgwr7a.mpg
# 528: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobbas2p.mpg
# 534: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgac4p.mpg
# 540: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbii2p.mpg
# 546: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswau8n.mpg
# 552: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbix5s.mpg
# 558: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbiizn.mpg
# 564: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgac2n.mpg
# 570: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolrik5a.mpg
# 576: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbwo3a.mpg
# 582: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbwu6p.mpg
# 588: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrih1s.mpg
# 594: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbwe5s.mpg
# 600: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbwy7s.mpg
# 606: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwwf6n.mpg
# 612: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrab3a.mpg
# 618: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwbf2n.mpg
# 624: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwbq7a.mpg
# 630: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwal4p.mpg
# 636: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbax9s.mpg
# 642: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgayzn.mpg
# 648: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbbe3a.mpg
# 654: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgwb7a.mpg
# 660: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbai5s.mpg
# 666: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoprbj7a.mpg
# 672: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbii3a.mpg
# 678: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolgbm3s.mpg
# 684: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoprwd6p.mpg
# 690: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoprwj8n.mpg
# 696: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbbezn.mpg
# 702: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgwlzn.mpg
# 708: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswbv5a.mpg
# 714: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwbs2p.mpg
# 720: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobbwgzn.mpg
# 726: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobrwg6n.mpg
# 732: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobrwa5a.mpg
# 738: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswio3a.mpg
# 744: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobris3s.mpg
# 750: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrihzn.mpg
# 756: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgak2n.mpg
# 762: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolgir9s.mpg
# 768: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswbc3a.mpg
# 774: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoprwkzp.mpg
# 780: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwwy5a.mpg
# 786: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgai6n.mpg
# 792: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobrif7a.mpg
# 798: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobbaf5a.mpg
# 804: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwwq9s.mpg
# 810: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrwv3a.mpg
# 816: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobrif5s.mpg
# 822: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbai6p.mpg
# 828: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrabzn.mpg
# 834: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgic1a.mpg
# 840: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbakzn.mpg
# 846: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgbh5s.mpg
# 852: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgaezp.mpg
# 858: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolrwz3s.mpg
# 864: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbbe1s.mpg
# 870: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolrbe9a.mpg
# 876: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbbp5a.mpg
# 882: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrah4n.mpg
# 888: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolrwl5s.mpg
# 894: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbivzp.mpg
# 900: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgivzn.mpg
# 906: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgbbzn.mpg
# 912: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwie6p.mpg
# 918: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgwe8p.mpg
# 924: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgid4n.mpg
# 930: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbax8n.mpg
# 936: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwie4n.mpg
# 942: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrah6p.mpg
# 948: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbig4n.mpg
# 954: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrah7a.mpg
# 960: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrbb6p.mpg
# 966: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopriv7a.mpg
# 972: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwij2n.mpg
# 978: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobragzp.mpg
# 984: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbwe6p.mpg
# 990: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobbws9s.mpg
# 996: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgid7a.mpg
# saving numpy
# 1002: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbwp8p.mpg
# 1008: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrah5s.mpg
# 1014: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbij8p.mpg
# 1020: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolgwa1a.mpg
# 1026: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswbo8n.mpg
# 1032: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgbr2p.mpg
# 1038: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgak3s.mpg
# 1044: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgwqzp.mpg
# 1050: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrbizp.mpg
# 1056: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswbi7a.mpg
# 1062: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbbh4p.mpg
# different size, skip
# different size, skip
# different size, skip
# different size, skip
# different size, skip
# different size, skip
# 1062: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbao9s.mpg
# 1068: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgig7s.mpg
# 1074: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgad9s.mpg
# 1080: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolrbr4n.mpg
# 1086: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwba6p.mpg
# 1092: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgib8n.mpg
# 1098: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolgaf7a.mpg
# 1104: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwig1s.mpg
# 1110: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwwf8p.mpg
# 1116: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoprbx4p.mpg
# 1122: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbbbzp.mpg
# 1128: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbii1s.mpg
# 1134: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgwu7s.mpg
# 1140: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwal3s.mpg
# 1146: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobbir6n.mpg
# 1152: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbwe7a.mpg
# 1158: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgan7a.mpg
# 1164: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobbil5a.mpg
# 1170: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosban2n.mpg
# 1176: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwwrzp.mpg
# 1182: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwam8n.mpg
# 1188: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgapzn.mpg
# 1194: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolgaz8p.mpg
# 1200: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbinzp.mpg
# 1206: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbaq7a.mpg
# 1212: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbwb2n.mpg
# 1218: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwwe3a.mpg
# 1224: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrbi1a.mpg
# 1230: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwix2p.mpg
# 1236: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwwuzn.mpg
# different size, skip
# different size, skip
# different size, skip
# different size, skip
# different size, skip
# different size, skip
# 1236: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobrwt5s.mpg
# 1242: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwat5a.mpg
# 1248: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwbf3s.mpg
# 1254: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswib5a.mpg
# 1260: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolgas3s.mpg
# 1266: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwwz9s.mpg
# 1272: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobbaf3s.mpg
# 1278: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbac3a.mpg
# 1284: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbbi8n.mpg
# 1290: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwag6p.mpg
# 1296: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbit4p.mpg
# 1302: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwbt8p.mpg
# 1308: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgbjzn.mpg
# 1314: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrbo3s.mpg
# 1320: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbwr2n.mpg
# 1326: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbaq4n.mpg
# 1332: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoprac9a.mpg
# 1338: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbix6p.mpg
# 1344: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobbiz3a.mpg
# 1350: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwafzp.mpg
# 1356: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgix7s.mpg
# 1362: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwbf4p.mpg
# 1368: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoprap4n.mpg
# 1374: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwbd7s.mpg
# 1380: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoprbx5a.mpg
# 1386: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgbc6n.mpg
# 1392: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwig2p.mpg
# 1398: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgwd3a.mpg
# 1404: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbib9a.mpg
# 1410: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgia2n.mpg
# 1416: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbwj2n.mpg
# 1422: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswab9a.mpg
# 1428: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbba8n.mpg
# 1434: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbib7s.mpg
# 1440: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwbn5a.mpg
# 1446: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbav5a.mpg
# 1452: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbia1s.mpg
# 1458: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgwd1s.mpg
# 1464: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgbh4n.mpg
# 1470: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobbbm1s.mpg
# 1476: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobbas1s.mpg
# 1482: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbbc6p.mpg
# 1488: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosria7s.mpg
# 1494: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwad4p.mpg
# 1500: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolgbg1a.mpg
# 1506: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopraj1s.mpg
# 1512: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolgbs6n.mpg
# 1518: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobbwm5s.mpg
# 1524: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbap1a.mpg
# 1530: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoprwx7s.mpg
# 1536: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoprbx2n.mpg
# 1542: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwbd8p.mpg
# 1548: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwwu3a.mpg
# 1554: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopraxzp.mpg
# 1560: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgbj1s.mpg
# 1566: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbad8p.mpg
# 1572: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwbz7a.mpg
# 1578: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoprav9s.mpg
# 1584: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoprax1a.mpg
# 1590: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwbf5a.mpg
# 1596: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwir5a.mpg
# 1602: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgaq8p.mpg
# 1608: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgwb6p.mpg
# 1614: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswiu5s.mpg
# 1620: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswbv4p.mpg
# 1626: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolrby9s.mpg
# 1632: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwiy9a.mpg
# 1638: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgwu8p.mpg
# 1644: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgbp5s.mpg
# 1650: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgwi1a.mpg
# 1656: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgbr1s.mpg
# 1662: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwiy7s.mpg
# 1668: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbwxzn.mpg
# 1674: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbib8p.mpg
# 1680: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgbu2n.mpg
# 1686: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwwf9a.mpg
# 1692: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrin4n.mpg
# 1698: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbbc4n.mpg
# 1704: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgak4p.mpg
# 1710: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrih2p.mpg
# 1716: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgak5a.mpg
# 1722: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbim9s.mpg
# 1728: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwij4p.mpg
# 1734: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbbrzp.mpg
# 1740: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgwo3s.mpg
# 1746: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbbu3a.mpg
# 1752: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoprbd1s.mpg
# 1758: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolrwz4p.mpg
# 1764: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobbbz9s.mpg
# 1770: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolgwg5a.mpg
# 1776: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbaq6p.mpg
# 1782: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbit5a.mpg
# 1788: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobril8n.mpg
# 1794: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwbg8n.mpg
# 1800: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwidzp.mpg
# 1806: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwik9s.mpg
# 1812: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolgiz2n.mpg
# 1818: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgan4n.mpg
# 1824: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrbu8p.mpg
# 1830: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbwh7s.mpg
# 1836: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgwx4p.mpg
# 1842: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolgwt2p.mpg
# 1848: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolgil5s.mpg
# 1854: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolgwm9a.mpg
# 1860: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgbn9s.mpg
# 1866: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgah3a.mpg
# 1872: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolriyzn.mpg
# 1878: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswwc5s.mpg
# 1884: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopriv5s.mpg
# 1890: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoprap6p.mpg
# 1896: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobbif1a.mpg
# 1902: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwbn4p.mpg
# 1908: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwip6n.mpg
# 1914: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolgbm5a.mpg
# 1920: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgbc7s.mpg
# 1926: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbat7s.mpg
# 1932: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbig7a.mpg
# 1938: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolgaf6p.mpg
# 1944: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbid4p.mpg
# 1950: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosran8n.mpg
# 1956: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswiu6p.mpg
# 1962: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoprbp8n.mpg
# 1968: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwax5s.mpg
# 1974: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgix8p.mpg
# 1980: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbiv1a.mpg
# 1986: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwwn6n.mpg
# 1992: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgii4p.mpg
# 1998: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwbq6p.mpg
# saving numpy
# 2004: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolgam1a.mpg
# 2010: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobrbg2n.mpg
# 2016: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwwezn.mpg
# 2022: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoprwj9s.mpg
# 2028: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswai1s.mpg
# 2034: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbwp9a.mpg
# 2040: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoprwq2n.mpg
# 2046: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwbz4n.mpg
# 2052: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgbj3a.mpg
# 2058: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbac2p.mpg
# 2064: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgah1s.mpg
# 2070: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolrbl3a.mpg
# 2076: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobrimzp.mpg
# 2082: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbai4n.mpg
# 2088: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgwizp.mpg
# 2094: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwat3s.mpg
# 2100: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoprac8p.mpg
# 2106: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbby5a.mpg
# 2112: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbwr3s.mpg
# 2118: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrbo4p.mpg
# 2124: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgan6p.mpg
# 2130: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobrif6p.mpg
# 2136: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobbaz5s.mpg
# 2142: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgwx2n.mpg
# 2148: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobbwm6p.mpg
# 2154: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbij7s.mpg
# 2160: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbwd1a.mpg
# 2166: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolgbm4p.mpg
# 2172: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolgwt1s.mpg
# 2178: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgwz1a.mpg
# 2184: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbaa6p.mpg
# 2190: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbby2n.mpg
# 2196: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbbp2n.mpg
# 2202: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwbkzn.mpg
# 2208: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrbb4n.mpg
# 2214: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwaj9a.mpg
# 2220: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbat9a.mpg
# 2226: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbav4p.mpg
# 2232: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgbu4p.mpg
# 2238: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbin1a.mpg
# 2244: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopriv4n.mpg
# 2250: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbbv6n.mpg
# 2256: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgbe5a.mpg
# 2262: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolriezp.mpg
# 2268: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobram2n.mpg
# 2274: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolrar1s.mpg
# 2280: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbbc7a.mpg
# 2286: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgid6p.mpg
# 2292: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoprii6n.mpg
# 2298: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgae1a.mpg
# 2304: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwip9a.mpg
# 2310: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgwj4n.mpg
# 2316: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgwy8n.mpg
# 2322: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwba5s.mpg
# 2328: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrwvzn.mpg
# 2334: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolgiz5a.mpg
# 2340: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswih6n.mpg
# 2346: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolgal8n.mpg
# 2352: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrbo5a.mpg
# 2358: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbbk5s.mpg
# 2364: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrwi5a.mpg
# 2370: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgwx3s.mpg
# 2376: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobbbs6p.mpg
# 2382: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoprac7s.mpg
# 2388: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbat6n.mpg
# 2394: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolrid8n.mpg
# 2400: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgwo5a.mpg
# 2406: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswbpzp.mpg
# 2412: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolrwr8n.mpg
# 2418: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgij8n.mpg
# 2424: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgaq9a.mpg
# 2430: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwwmzn.mpg
# 2436: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswbi5s.mpg
# 2442: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrit8n.mpg
# 2448: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgwzzp.mpg
# 2454: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbim8n.mpg
# 2460: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwbt7s.mpg
# 2466: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobram4p.mpg
# 2472: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwwk7a.mpg
# 2478: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgig6n.mpg
# 2484: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobrbtzn.mpg
# 2490: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswih8p.mpg
# 2496: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoprbdzn.mpg
# 2502: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgiv2p.mpg
# 2508: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbag8n.mpg
# 2514: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgay2p.mpg
# 2520: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgav5s.mpg
# 2526: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbiazn.mpg
# 2532: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbwk9s.mpg
# 2538: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbwc9s.mpg
# 2544: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgbe3s.mpg
# 2550: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgwd2p.mpg
# 2556: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbwozn.mpg
# 2562: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolrbl1s.mpg
# 2568: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbag9s.mpg
# 2574: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwwa9s.mpg
# 2580: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwws5s.mpg
# 2586: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswwi9s.mpg
# 2592: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbwx2p.mpg
# 2598: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgwe7s.mpg
# 2604: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswbi6p.mpg
# 2610: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobbbs5s.mpg
# 2616: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwbhzp.mpg
# 2622: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopraj2p.mpg
# 2628: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbit3s.mpg
# 2634: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwwr1a.mpg
# 2640: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwax4n.mpg
# 2646: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgwq1a.mpg
# 2652: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwae8n.mpg
# 2658: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwbd9a.mpg
# 2664: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrwi4p.mpg
# 2670: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwaz2p.mpg
# 2676: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobram3s.mpg
# 2682: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwbx8n.mpg
# 2688: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwbs3a.mpg
# 2694: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrih3a.mpg
# 2700: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwws7a.mpg
# 2706: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrau3s.mpg
# ...
# 5034: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolrwl7a.mpg
# 5040: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwwh2n.mpg
# 5046: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgin3a.mpg
# 5052: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgij9s.mpg
# 5058: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrbb7a.mpg
# 5064: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwaa3a.mpg
# 5070: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwwa8n.mpg
# 5076: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbib6n.mpg
# 5082: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgby4n.mpg
# 5088: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgin1s.mpg
# 5094: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbwb3s.mpg
# 5100: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobras6n.mpg
# 5106: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswbc2p.mpg
# 5112: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbwo2p.mpg
# 5118: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgaa6n.mpg
# 5124: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobbws8n.mpg
# 5130: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosban4p.mpg
# 5136: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwbt6n.mpg
# 5142: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobris2n.mpg
# 5148: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwba7a.mpg
# 5154: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobbir7s.mpg
# 5160: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobrbm6n.mpg
# 5166: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolrae2n.mpg
# 5172: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwij3s.mpg
# 5178: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgwr4n.mpg
# 5184: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolgifzn.mpg
# 5190: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwwy3s.mpg
# 5196: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrwb8n.mpg
# 5202: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbaa5s.mpg
# 5208: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbbc5s.mpg
# 5214: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwba4n.mpg
# 5220: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswwp3s.mpg
# 5226: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgib9s.mpg
# 5232: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrin5s.mpg
# 5238: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolgif3a.mpg
# 5244: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolgir8n.mpg
# 5250: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwbz6p.mpg
# 5256: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgwdzn.mpg
# 5262: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbbr1a.mpg
# 5268: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwwu2p.mpg
# 5274: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwip8p.mpg
# 5280: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgbk8p.mpg
# 5286: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobras9a.mpg
# 5292: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgbh6p.mpg
# 5298: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgikzp.mpg
# 5304: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgwb4n.mpg
# 5310: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobbbs4n.mpg
# 5316: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswio1s.mpg
# 5322: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrwo8p.mpg
# 5328: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoprbj4n.mpg
# 5334: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgbozp.mpg
# 5340: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswbo9s.mpg
# 5346: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbaa7a.mpg
# 5352: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobbir9a.mpg
# 5358: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwbg9s.mpg
# 5364: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoprip1s.mpg
# 5370: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolrwfzn.mpg
# 5376: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbia3a.mpg
# 5382: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswwi8n.mpg
# 5388: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolgil6p.mpg
# 5394: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobrbm9a.mpg
# 5400: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobrwt7a.mpg
# 5406: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwwh5a.mpg
# 5412: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolrae3s.mpg
# 5418: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrab2p.mpg
# 5424: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolgwm7s.mpg
# 5430: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoprap5s.mpg
# 5436: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobrag1a.mpg
# 5442: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolgas5a.mpg
# 5448: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwwbzp.mpg
# 5454: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobbaf2n.mpg
# 5460: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbwb4p.mpg
# 5466: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobrba1a.mpg
# 5472: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgaq6n.mpg
# 5478: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolrik2n.mpg
# 5484: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobbaz4n.mpg
# 5490: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoprbp9s.mpg
# 5496: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosban5a.mpg
# 5502: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrao1a.mpg
# 5508: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgwo2n.mpg
# 5514: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswbp1a.mpg
# 5520: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgiq3s.mpg
# 5526: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbbk4n.mpg
# 5532: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobbaszn.mpg
# 5538: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwbl9a.mpg
# 5544: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgiq2n.mpg
# 5550: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbwe4n.mpg
# 5556: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrwb9s.mpg
# 5562: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwit1a.mpg
# 5568: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswwc7a.mpg
# 5574: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswab8p.mpg
# 5580: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgap1s.mpg
# 5586: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswwv6n.mpg
# 5592: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolriq9a.mpg
# 5598: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswwv9a.mpg
# 5604: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrbo2n.mpg
# 5610: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobwaa1s.mpg
# 5616: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgbn8n.mpg
# 5622: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolrwl4n.mpg
# 5628: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbaq5s.mpg
# 5634: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswwp4p.mpg
# 5640: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobrwnzn.mpg
# 5646: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgbh7a.mpg
# 5652: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgbj2p.mpg
# 5658: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbav3s.mpg
# 5664: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgan5s.mpg
# 5670: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbwy8p.mpg
# 5676: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobgahzn.mpg
# 5682: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbat8p.mpg
# 5688: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgwr6p.mpg
# 5694: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgii5a.mpg
# 5700: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolrae5a.mpg
# 5706: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgio7s.mpg
# 5712: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwwe2p.mpg
# 5718: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbbn6n.mpg
# 5724: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgbrzn.mpg
# 5730: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbio4n.mpg
# 5736: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolgaz7s.mpg
# 5742: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswib2n.mpg
# 5748: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoprwq4p.mpg
# 5754: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswaizn.mpg
# 5760: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbwx1s.mpg
# different size, skip
# different size, skip
# different size, skip
# different size, skip
# different size, skip
# different size, skip
# 5760: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrbh8n.mpg
# 5766: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswwc6p.mpg
# 5772: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopriv6p.mpg
# 5778: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgwe9a.mpg
# 5784: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosgbx1a.mpg
# 5790: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolrie1a.mpg
# 5796: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolrak9a.mpg
# 5802: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwiy8p.mpg
# 5808: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswao6p.mpg
# 5814: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopgwl3a.mpg
# 5820: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbad7s.mpg
# 5826: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videobrwn1s.mpg
# 5832: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswih9a.mpg
# 5838: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoprip3a.mpg
# 5844: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolwbl6n.mpg
# 5850: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwaq2p.mpg
# 5856: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbbu2p.mpg
# 5862: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswbczn.mpg
# 5868: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbbn8p.mpg
# 5874: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoswiozn.mpg
# 5880: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosbbn9a.mpg
# 5886: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbby4p.mpg
# 5892: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videosrwi3s.mpg
# 5898: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videolbad6n.mpg
# 5904: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwic9s.mpg
# 5910: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videoprwq5a.mpg
# 5916: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopripzn.mpg
# 5922: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopwaj7s.mpg
# 5928: reading from /home/ubuntu/assignments/machine-lip-reading/preprocessing/../data/s1/videopbav2n.mpg
# saving numpy
